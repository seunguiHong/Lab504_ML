# %%
# ============================================================
# Ridge / Lasso / ElasticNet / RF / ExtraTrees / XGB
# X = fwds
# Baselines: naive / condmean / cs_yhat
# Console output only
# ============================================================

import os, sys, warnings
import numpy as np
import pandas as pd
warnings.filterwarnings("ignore")

from rolling_framework import Machine

# ---------------- Paths ----------------
DATA_DIR = "data"
Y_FILE = os.path.join(DATA_DIR, "exrets.csv")
FWD_FILE = os.path.join(DATA_DIR, "fwds.csv")
CS_YHAT_FILE = os.path.join(DATA_DIR, "cs_yhat.csv")

BURN_START, BURN_END = "197108", "199001"
PERIOD_START, PERIOD_END = "197108", "202312"
HORIZON = 12
MATURITIES = ["xr_2", "xr_3", "xr_5", "xr_7", "xr_10"]

# ---------------- Helpers ----------------
def _load_csv(path):
    try:
        return pd.read_csv(path, index_col="Time")
    except FileNotFoundError:
        sys.exit(f"Missing file: {path}")

def _align_time(*dfs):
    idx = None
    for d in dfs:
        idx = d.index if idx is None else idx.intersection(d.index)
    return [d.loc[idx].sort_index() for d in dfs]

def _to_series(x, index):
    if isinstance(x, pd.Series):
        return x.reindex(index)
    if isinstance(x, pd.DataFrame):
        return x.squeeze().reindex(index)
    try:
        return pd.Series(float(x), index=index)
    except Exception:
        return pd.Series(np.nan, index=index)

def _print_r2_block(title, m, cs_path=None):
    print(f"\n==== {title} ====")
    r2_naive = m.R2OOS(baseline="naive")
    r2_cond  = m.R2OOS(baseline="condmean")
    r2_cs    = m.R2OOS(baseline="cs_yhat", cs_path=cs_path) if cs_path else np.nan

    cols = getattr(m, "targets", getattr(m, "y", pd.DataFrame()).columns)
    s_naive, s_cond, s_cs = map(lambda x: _to_series(x, cols), [r2_naive, r2_cond, r2_cs])

    tbl = pd.DataFrame({
        "R2OOS_naive": s_naive,
        "R2OOS_condmean": s_cond,
        "R2OOS_cs_yhat": s_cs
    })
    print(tbl.round(4))
    print("Mean:", tbl.mean(axis=0, skipna=True).round(4).to_dict())

def run_model(model_type, option, grid, X, y, cs_path, title):
    m = Machine(
        X, y,
        model_type=model_type, option=option, params_grid=grid,
        burn_in_start=BURN_START, burn_in_end=BURN_END,
        period=[PERIOD_START, PERIOD_END],
        forecast_horizon=HORIZON,
    )
    print(f"\n▶ {title}")
    m.training()
    _print_r2_block(title, m, cs_path=cs_path)

# ---------------- Data ----------------
y = _load_csv(Y_FILE)
fwd = _load_csv(FWD_FILE)

y_cols = [c for c in MATURITIES if c in y.columns]
if not y_cols:
    sys.exit("MATURITIES not found in exrets.csv")
y = y[y_cols]

y, fwd = _align_time(y, fwd)
X = fwd.copy()

# Clean cs_yhat
cs = _load_csv(CS_YHAT_FILE)
cs = cs[~cs.index.duplicated(keep="last")]
cs = cs.reindex(columns=y.columns)
CS_CLEAN_FILE = os.path.join(DATA_DIR, "cs_yhat.csv")
cs.to_csv(CS_CLEAN_FILE)

print("✓ data:", {"X": X.shape, "y": y.shape, "cs_yhat": cs.shape})

# ---------------- Penalized Models ----------------
grid_lasso = {"reg__alpha": np.logspace(-3, 2, 5)}
grid_ridge = {"reg__alpha": np.logspace(-3, 2, 5)}
grid_enet  = {"reg__alpha": np.logspace(-3, 2, 5), "reg__l1_ratio": [0.1, 0.3, 0.5]}

run_model("Penalized", "lasso",      grid_lasso, X, y, CS_CLEAN_FILE, "Lasso")
run_model("Penalized", "ridge",      grid_ridge, X, y, CS_CLEAN_FILE, "Ridge")
run_model("Penalized", "elasticnet", grid_enet,  X, y, CS_CLEAN_FILE, "ElasticNet")

# ---------------- Tree Models ----------------
grid_rf = {
    "model__estimator__n_estimators": [300],
    "model__estimator__max_depth": [2, 8],
    "model__estimator__min_samples_split": [2, 4],
    "model__estimator__min_samples_leaf": [1, 2, 4],
    "model__estimator__max_features": [0.25, 0.5, 1],
}
grid_et = {
    "model__estimator__n_estimators": [300],
    "model__estimator__max_depth": [2, 8],
    "model__estimator__min_samples_split": [2, 4],
    "model__estimator__min_samples_leaf": [1, 2, 4],
    "model__estimator__max_features": [0.25, 0.5, 1],
}
grid_xgb = {
    "model__estimator__n_estimators": [300],
    "model__estimator__max_depth": [2, 4],
    "model__estimator__learning_rate": [0.01],
    "model__estimator__subsample": [0.7, 0.5],
    "model__estimator__reg_lambda": [0.1, 1.0],
}

run_model("Tree", "rf",  grid_rf,  X, y, CS_CLEAN_FILE, "RandomForest")
run_model("Tree", "et",  grid_et,  X, y, CS_CLEAN_FILE, "ExtraTrees")
run_model("Tree", "xgb", grid_xgb, X, y, CS_CLEAN_FILE, "XGBoost")

print("\n✓ done")
# Out:
# ✓ data: {'X': (629, 10), 'y': (629, 5), 'cs_yhat': (612, 5)}
#
# ▶ Lasso
# Penalized rolling:   0%|          | 0/408 [00:00<?, ?it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.522e-03, tolerance: 1.991e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.886e+00, tolerance: 1.948e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:   0%|          | 1/408 [00:04<27:13,  4.01s/it]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.703e-03, tolerance: 2.155e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.051e-01, tolerance: 3.180e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.091e+00, tolerance: 1.950e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.512e-01, tolerance: 2.301e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.659e+00, tolerance: 8.822e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.302e+01, tolerance: 3.265e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.134e+01, tolerance: 7.946e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.916e+01, tolerance: 1.911e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.481e-01, tolerance: 2.249e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.627e+00, tolerance: 8.409e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.344e+01, tolerance: 3.056e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.526e+01, tolerance: 7.208e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.950e+01, tolerance: 1.711e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.636e-01, tolerance: 2.263e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e+00, tolerance: 8.433e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.109e+00, tolerance: 3.057e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.442e+01, tolerance: 7.211e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.662e+01, tolerance: 1.712e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:   1%|          | 5/408 [00:04<04:11,  1.60it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.268e-02, tolerance: 2.172e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.960e-02, tolerance: 7.920e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.003e-01, tolerance: 2.807e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.687e+00, tolerance: 6.362e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.982e+00, tolerance: 1.494e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.396e-02, tolerance: 5.978e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.681e-01, tolerance: 1.399e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  10%|█         | 41/408 [00:05<00:13, 26.52it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.090e-03, tolerance: 3.580e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.113e-01, tolerance: 8.794e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e-01, tolerance: 1.646e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.354e-03, tolerance: 3.706e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.674e-02, tolerance: 4.409e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.322e-01, tolerance: 8.902e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.906e-01, tolerance: 1.710e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  11%|█         | 45/408 [00:05<00:13, 27.88it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.617e-03, tolerance: 3.085e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.041e-02, tolerance: 3.837e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.945e-01, tolerance: 8.190e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.066e-01, tolerance: 1.668e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.166e-02, tolerance: 2.778e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.873e-02, tolerance: 3.409e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.345e-01, tolerance: 7.406e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.152e-01, tolerance: 1.505e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.135e-02, tolerance: 2.527e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.418e-02, tolerance: 2.992e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.805e-01, tolerance: 6.597e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.109e+00, tolerance: 1.324e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.461e-02, tolerance: 2.213e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.386e-01, tolerance: 2.461e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.418e+00, tolerance: 5.467e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.196e-01, tolerance: 1.079e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.503e+00, tolerance: 1.079e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  12%|█▏        | 49/408 [00:05<00:12, 29.29it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.104e-02, tolerance: 2.173e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.603e-01, tolerance: 2.245e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.767e+00, tolerance: 4.864e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.578e+00, tolerance: 9.375e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.217e-02, tolerance: 4.864e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.902e-01, tolerance: 9.375e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.430e-01, tolerance: 9.405e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.308e-02, tolerance: 2.519e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.630e-01, tolerance: 2.472e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.348e+00, tolerance: 5.074e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.180e+00, tolerance: 9.405e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e-02, tolerance: 3.399e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.222e-02, tolerance: 1.125e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.111e-01, tolerance: 6.218e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.196e+00, tolerance: 1.112e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.247e-02, tolerance: 4.113e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e-01, tolerance: 4.052e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.006e+00, tolerance: 7.245e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.470e+00, tolerance: 1.262e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  13%|█▎        | 53/408 [00:05<00:11, 29.70it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.074e-02, tolerance: 5.051e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.133e-01, tolerance: 5.224e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.322e+00, tolerance: 9.234e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.369e+00, tolerance: 1.591e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.958e-02, tolerance: 5.792e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.536e-01, tolerance: 1.072e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.437e+00, tolerance: 1.845e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.864e-02, tolerance: 6.715e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.713e-01, tolerance: 7.320e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.078e-01, tolerance: 2.221e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.746e-02, tolerance: 7.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.805e-01, tolerance: 8.958e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.159e+00, tolerance: 2.750e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  14%|█▍        | 57/408 [00:05<00:11, 31.37it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.802e-02, tolerance: 9.030e-03
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.284e-01, tolerance: 1.067e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.151e-01, tolerance: 3.343e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.676e-01, tolerance: 1.227e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.992e-01, tolerance: 2.164e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.630e+00, tolerance: 3.740e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.606e-01, tolerance: 1.384e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.685e-01, tolerance: 2.411e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.104e+00, tolerance: 4.106e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.403e-01, tolerance: 1.521e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.902e-01, tolerance: 2.641e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.610e+00, tolerance: 4.453e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  15%|█▍        | 61/408 [00:05<00:10, 32.80it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.067e-01, tolerance: 1.561e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.681e-01, tolerance: 2.700e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.576e-01, tolerance: 4.522e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.495e-01, tolerance: 2.702e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.944e-01, tolerance: 4.511e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.635e-01, tolerance: 2.696e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.932e-01, tolerance: 4.509e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.870e-01, tolerance: 1.559e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.939e-01, tolerance: 2.705e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.080e-01, tolerance: 4.537e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  16%|█▌        | 65/408 [00:05<00:10, 32.65it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.886e-01, tolerance: 1.538e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.237e-01, tolerance: 2.681e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.119e-01, tolerance: 4.567e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.001e-01, tolerance: 4.654e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  17%|█▋        | 69/408 [00:06<00:10, 32.69it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.206e-01, tolerance: 5.018e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.306e-02, tolerance: 1.182e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.582e-01, tolerance: 4.976e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e-01, tolerance: 1.636e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  18%|█▊        | 73/408 [00:06<00:10, 33.07it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.019e-01, tolerance: 4.786e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.717e-01, tolerance: 1.596e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.864e-02, tolerance: 4.618e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.051e-01, tolerance: 5.224e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.777e-02, tolerance: 4.438e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.734e-01, tolerance: 2.890e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.216e+00, tolerance: 5.290e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  19%|█▉        | 77/408 [00:06<00:09, 33.11it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.497e-01, tolerance: 2.929e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.506e+00, tolerance: 5.399e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.317e+00, tolerance: 5.487e-01
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling:  20%|█▉        | 81/408 [00:06<00:09, 33.94it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.217e-01, tolerance: 5.457e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.277e+00, tolerance: 5.352e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.434e-01, tolerance: 5.365e-01
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.115e+02, tolerance: 1.653e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.138e+04, tolerance: 6.057e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.905e+01, tolerance: 5.454e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.032e+03, tolerance: 3.150e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.281e+02, tolerance: 1.653e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.251e+03, tolerance: 6.057e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.636e+03, tolerance: 3.150e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.524e+03, tolerance: 6.057e+00
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling: 100%|█████████▉| 407/408 [00:23<00:00, 11.97it/s]/Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.764e-01, tolerance: 1.679e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.676e+00, tolerance: 6.057e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.252e+01, tolerance: 1.935e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.867e+01, tolerance: 1.636e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.472e+01, tolerance: 3.708e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.357e-02, tolerance: 1.679e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.714e+02, tolerance: 7.161e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.898e-01, tolerance: 6.057e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.690e+00, tolerance: 1.636e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.722e+00, tolerance: 1.935e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.838e+02, tolerance: 5.454e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.839e+00, tolerance: 3.708e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.237e+02, tolerance: 5.454e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.682e-02, tolerance: 1.679e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.075e+01, tolerance: 7.161e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.423e-01, tolerance: 6.057e-02
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.262e+02, tolerance: 1.653e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.825e+03, tolerance: 1.653e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.055e+01, tolerance: 5.454e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.842e+00, tolerance: 1.935e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.317e+00, tolerance: 3.708e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.087e+03, tolerance: 3.150e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.252e+01, tolerance: 7.161e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.354e+03, tolerance: 3.150e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.366e+03, tolerance: 6.057e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.402e+02, tolerance: 1.653e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.150e+04, tolerance: 6.057e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.682e+03, tolerance: 3.150e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/ethan_hong/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.624e+03, tolerance: 6.057e+00
#   model = cd_fast.enet_coordinate_descent(
# Penalized rolling: 100%|██████████| 408/408 [00:23<00:00, 17.39it/s]
# ==== ElasticNet ====
#        R2OOS_naive  R2OOS_condmean  R2OOS_cs_yhat
# xr_2        0.0830         -0.0425         0.0556
# xr_3        0.0810         -0.0628        -0.0167
# xr_5        0.0772         -0.0853        -0.0762
# xr_7        0.0624         -0.1000        -0.1181
# xr_10       0.0287         -0.1281        -0.1998
# Mean: {'R2OOS_naive': 0.0665, 'R2OOS_condmean': -0.0837, 'R2OOS_cs_yhat': -0.071}
#
# ▶ RandomForest
# Tree rolling: 100%|██████████| 408/408 [1:09:43<00:00, 10.25s/it]
# ==== RandomForest ====
#        R2OOS_naive  R2OOS_condmean  R2OOS_cs_yhat
# xr_2       -0.0709         -0.2152        -0.1028
# xr_3       -0.0703         -0.2360        -0.1842
# xr_5       -0.0497         -0.2331        -0.2241
# xr_7       -0.0548         -0.2364        -0.2579
# xr_10      -0.0571         -0.2267        -0.3059
# Mean: {'R2OOS_naive': -0.0606, 'R2OOS_condmean': -0.2295, 'R2OOS_cs_yhat': -0.215}
#
# ▶ ExtraTrees
# Tree rolling: 100%|██████████| 408/408 [40:19<00:00,  5.93s/it]
# ==== ExtraTrees ====
#        R2OOS_naive  R2OOS_condmean  R2OOS_cs_yhat
# xr_2        0.0159         -0.1178        -0.0135
# xr_3       -0.0035         -0.1598        -0.1102
# xr_5       -0.0080         -0.1848        -0.1755
# xr_7       -0.0250         -0.2021        -0.2224
# xr_10      -0.0566         -0.2268        -0.3053
# Mean: {'R2OOS_naive': -0.0154, 'R2OOS_condmean': -0.1783, 'R2OOS_cs_yhat': -0.1654}
#
# ▶ XGBoost
# Tree rolling: 100%|██████████| 408/408 [04:11<00:00,  1.62it/s]
# ==== XGBoost ====
#        R2OOS_naive  R2OOS_condmean  R2OOS_cs_yhat
# xr_2       -0.1356         -0.2912        -0.1695
# xr_3       -0.1729         -0.3568        -0.2976
# xr_5       -0.1632         -0.3682        -0.3565
# xr_7       -0.1599         -0.3610        -0.3831
# xr_10      -0.1366         -0.3203        -0.4040
# Mean: {'R2OOS_naive': -0.1536, 'R2OOS_condmean': -0.3395, 'R2OOS_cs_yhat': -0.3222}
#
# ✓ done
